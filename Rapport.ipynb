# %% [markdown]
# # Energy Management in Building
# ## 1. Building Description
# We decided to work on a workspace, with a room with two desks (25,9 m2) and a kitchen (10,1 m2). Here is the plan :
# ![Description](PLAN_projet.png)
